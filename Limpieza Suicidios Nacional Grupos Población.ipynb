# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('defunciones-causa-total.csv', sep=';', encoding='ISO-8859-1')

# %%
df
# Out:
#                               Causa de muerte     Sexo              Edad  \
# 0     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 1     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 2     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 3     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 4     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 5     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 6     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 7     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 8     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 9     098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 10    098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# 11    098  Suicidio y lesiones autoinfligidas    Total  Todas las edades
# ...

# %%
df = df.drop('Causa de muerte', axis=1)

# %%
df.rename({'Total':'Suicidios', 'Periodo':'Año'}, axis=1, inplace=True)

# %%
df.to_csv('suicidios_limpio.csv')
